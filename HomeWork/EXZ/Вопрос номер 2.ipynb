# %% [markdown]
# 1) Бутстреп и пуассоновский бутстреп. Как работает, почему используется, плюсы и минусы. Границы применимости.
# Бакетное преобразование метрики: чем похоже на бутстреп и чем отличается.
#
# 2) Устройство промышленных АБ-платформ, что необходимо, как разбивать пользователей на группы
#
# 3) Методы приближенного подсчета уникальных значений (uniq, Hyperloglog)
#
# 4) Статистические тесты как частные случаи линейной регрессии.
#
# 5) Теорема Фриша-Во-Лавелла и ее связь с CUPED
#
# 6) Вариации алгоритмов градиентного спуска и то, какие проблемы они решают
#
# 7) Задача о многоруком бандите без контекста и стратегии ее решения.
#
# 8) Методы приближенного поиска ближайших соседей
#
# 9) Ratio-метрики, чем это плохо и какие методы использовать чтобы "починить" проблемы

# %% [markdown]
# https://www.kaggle.com/datasets/alexxl/zvuk-dataset
#
#     * Время за сессию
#     * Время на юзера
#     * Доля «непрослушанных» треков
#
#
#
# 1. Провести EDA, выяснить, что в большей степени влияет на указанные метрики.
#
# 2. Насколько перспективным было бы использовать CUPED (сильно ли коррелирует текущая история метрики с ее предысторией?).
#
# 3. В течение какого времени необходимо проводить тест (и на каком объеме аудитории), чтобы «заметить» изменение в 3-5% на указанной метрике.
